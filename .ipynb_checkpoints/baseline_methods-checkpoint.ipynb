# %%
import torch
import numpy
import matplotlib.pyplot as plt
import rawpy
import cv2

# %%
with rawpy.imread("data/a0001-jmac_DSC1459.dng") as raw:
    print(raw.raw_image)
    print(raw.raw_image.shape)
# Out:
# [[1070 1398 1047 ... 1003  930  191]
#  [1372  585 1407 ...  371  995  188]
#  [1040 1372 1070 ... 1017  959  193]
#  ...
#  [ 367  298  488 ...  625  846  194]
#  [ 252  508  215 ...  813  358  200]
#  [ 562  390  568 ...  648  786  190]]
# (2014, 3040)

# %% [markdown]
# resize them to the same size by interpolation.

# %%
edited = cv2.imread("/media/samuel/HDD1TB/data.csail.mit.edu/graphics/fivek/img/tiff16_a/a0001-jmac_DSC1459.tif",1)
print(edited.shape)
# Out:
# (2000, 3008, 3)

# %%
plt.imshow(edited)

# %%
edit2 = cv2.resize(edited, )
